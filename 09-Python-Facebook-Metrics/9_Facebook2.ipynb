# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#seperator is semicolon
df = pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
# Line plot with legend outside the figure
ax = df.plot(kind='line', figsize=(10, 6))
plt.title('Original DataFrame (Line Plot)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)

# Move legend outside the figure
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## Create data subsets for type of post

# %%
df_photo=df[df["Type"]=="Photo"]
df_photo.head(5)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
# Line plot
plt.figure(figsize=(10, 6))
df_photo.plot(kind='line', figsize=(10, 6))
plt.title('Photo DataFrame (Line Plot)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# %% [markdown]
# ## creating a subset of type=status

# %%
df_status=df[df["Type"]=="Status"]
df_status.head(5)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## creating a subset of type=video

# %%
df_video=df[df["Type"]=="Video"]
df_video.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
# Bar graph
plt.figure(figsize=(10, 6))
df_video.plot(kind='bar', figsize=(10, 6))
plt.title('Video DataFrame (Bar Graph)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# Line plot
plt.figure(figsize=(10, 6))
df_video.plot(kind='line', figsize=(10, 6))
plt.title('Video DataFrame (Line Plot)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# %% [markdown]
# ## creating a subset of type=Link

# %%
df_link=df[df["Type"]=="Link"]
df_link.head(5)
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
# Bar graph
plt.figure(figsize=(10, 6))
df_link.plot(kind='bar', figsize=(10, 6))
plt.title('Link DataFrame (Bar Graph)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# Line plot
plt.figure(figsize=(10, 6))
df_link.plot(kind='line', figsize=(10, 6))
plt.title('Link DataFrame (Line Plot)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# %% [markdown]
# # Merge two subsets
# ## merging subsets of photos and status

# %%
df_merged_ps=pd.concat([df_photo,df_status])
df_merged_ps
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
# Line plot
plt.figure(figsize=(10, 6))
df_merged_ps.plot(kind='line', figsize=(10, 6))
plt.title('Merged Photo and Status DataFrame (Line Plot)')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend outside the figure
plt.show()

# %%
#merged subsets
print("Photo subset shape: ")
df_photo.shape
# Out:
# Photo subset shape:
# (426, 19)

# %%
print("Status subset shape: ")
df_status.shape
# Out:
# Status subset shape:
# (45, 19)

# %%
print("Merged subset shape: ")
df_merged_ps.shape
# no of rows=> 426+45=471
# Out:
# Merged subset shape:
# (471, 19)

# %% [markdown]
# ## Sort Data on Page Total Likes

# %%
#sorting by the column by like
df_sort_like = df.sort_values(by=["like"])
df_sort_like.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 21    0.0                       1384                             2467
# 417   0.0                       1874                             2474
# 100   1.0                       1357                             2453
# 76    0.0                       1228                             2392
# 441   1.0                       1845                             2670
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Sorting by the column by comment

# %%
#sorting by the column by comment
df_sort_comments = df.sort_values(by=["comment"])
df_sort_comments.head(5)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 111            136736   Photo         1          10             6          8
# 276            126424   Photo         3           7             3          4
# 282            126345  Status         2           6             7         11
# 286            126141   Photo         1           6             5         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 499   NaN                       4188                             7292
# 111   0.0                       1261                             2158
# 276   1.0                       2316                             3611
# 282   0.0                      12044                            20327
# 286   1.0                       2431                             4180
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Sorting by the column = share

# %%
#sorting by the column = share
df_sort_share = df.sort_values(by=["share"])
df_sort_share.head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195  Photo         1           3             5          4
# 21             138414  Photo         1          12             7         10
# 436            100732  Photo         1           3             6         13
# 431            100732  Photo         1           3             7         12
# 117            136642  Photo         1          10             7         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 441   1.0                       1845                             2670
# 21    0.0                       1384                             2467
# 436   1.0                       9604                            16557
# 431   0.0                       4094                             7469
# 117   0.0                        729                             1374
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Add additional sorting methods

# %%
# Add additional sorting methods
df_sort_comment_desc = df.sort_values(by=["comment"], ascending=False)
df_sort_share_asc = df.sort_values(by=["share"], ascending=True)
df_sort_comment_desc
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
# ..                ...    ...       ...         ...           ...        ...
# 332            119198  Photo         3           5             2         12
# 333            119198  Photo         3           5             2          1
# 111            136736  Photo         1          10             6          8
# 103            137020  Photo         1          10             3          4
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
df_sort_share_asc
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195  Photo         1           3             5          4
# 21             138414  Photo         1          12             7         10
# 436            100732  Photo         1           3             6         13
# 431            100732  Photo         1           3             7         12
# 117            136642  Photo         1          10             7         11
# ..                ...    ...       ...         ...           ...        ...
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
# 120            136393  Photo         1          10             7          9
# 124            136393  Photo         1          10             7          6
# 164            135428  Photo         1           9             5         10
#
# ...

# %% [markdown]
# ## Transposing Data

# %%
#transposing the dataset basically means interchanging the rows and columns

df_transpose = df.transpose()
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # Another Transpose Method

# %%
# Another transpose method
df_transpose_alt = df.T
df_transpose_alt
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# ## Shape and Reshape data

# %%
# adding an index column to provide a unique value to each row entry to further melt and unmelt the data

df['index'] = range(1,len(df)+1)
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## Melting Data to long format

# %%
df_melted=pd.melt(df,id_vars=['Type','Category'],value_name='value',var_name='Metrics')
df_melted
# Out:
#         Type  Category           Metrics     value
# 0      Photo         2  Page total likes  139441.0
# 1     Status         2  Page total likes  139441.0
# 2      Photo         3  Page total likes  139441.0
# 3      Photo         2  Page total likes  139441.0
# 4      Photo         2  Page total likes  139441.0
# ...      ...       ...               ...       ...
# 8995   Photo         3             index     496.0
# 8996   Photo         2             index     497.0
# 8997   Photo         1             index     498.0
# 8998   Photo         3             index     499.0
# 8999   Photo         2             index     500.0
#
# [9000 rows x 4 columns]

# %%
# melting the data usin10g melt()

df_melted = pd.melt(df, id_vars='index',  value_vars='Total Interactions')
df_melted
# Out:
#      index            variable  value
# 0        1  Total Interactions    100
# 1        2  Total Interactions    164
# 2        3  Total Interactions     80
# 3        4  Total Interactions   1777
# 4        5  Total Interactions    393
# ..     ...                 ...    ...
# 495    496  Total Interactions     84
# 496    497  Total Interactions     75
# 497    498  Total Interactions    115
# 498    499  Total Interactions    136
# 499    500  Total Interactions    119
#
# [500 rows x 3 columns]

# %%
#melting the data using melt()

df_melted = pd.melt(df, id_vars='index',  value_vars='Type')
df_melted
# Out:
#      index variable   value
# 0        1     Type   Photo
# 1        2     Type  Status
# 2        3     Type   Photo
# 3        4     Type   Photo
# 4        5     Type   Photo
# ..     ...      ...     ...
# 495    496     Type   Photo
# 496    497     Type   Photo
# 497    498     Type   Photo
# 498    499     Type   Photo
# 499    500     Type   Photo
#
# [500 rows x 3 columns]

# %% [markdown]
# # Visualize melted data

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='variable', y='value', data=df_melted)
plt.title('Melted Data Visualization')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.barplot(x='variable', y='value', data=df_melted)
#       3 plt.title('Melted Data Visualization')
#       4 plt.xlabel('Metrics')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
# ...

# %% [markdown]
# ## Casting data to wide format

# %%
casting = pd.pivot_table(df,index=['Type','Category'],values='like', fill_value = 0)

# %%
casting.head()
# Out:
#                       like
# Type  Category
# Link  1          75.650000
#       2          32.000000
#       3          68.000000
# Photo 1         126.000000
#       2         235.857143

# %% [markdown]
# Calculate Engagement Rate

# %%
df['Engagement Rate'] = (df['Lifetime Engaged Users'] / df['Lifetime Post Total Reach']) * 100
df['Engagement Rate']
# Out:
# 0       6.468023
# 1      13.929254
# 2       7.335267
# 3       4.410709
# 4       9.262838
#          ...
# 495    15.649018
# 496    15.431034
# 497    16.543145
# 498    15.062560
# 499    13.467049
# Name: Engagement Rate, Length: 500, dtype: float64

# %% [markdown]
# # Visualize casting data

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Type', y='like', hue='Category', data=casting)
plt.title('Casting Data Visualization')
plt.xlabel('Post Type')
plt.ylabel('Average Likes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.barplot(x='Type', y='like', hue='Category', data=casting)
#       3 plt.title('Casting Data Visualization')
#       4 plt.xlabel('Post Type')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
# ...

# %% [markdown]
# # Identify best performing posts

# %%
best_posts = df.sort_values(by='Lifetime Post Total Reach', ascending=False)
best_posts.head(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 463             92186  Photo         3           2             7          2
# 277            126424  Video         1           6             2         13
# 380            111620  Photo         1           4             7         14
# 437            100732  Photo         1           3             6         10
# 279            126345  Photo         1           6             2          3
# 379            111620  Photo         3           4             1         14
# 71             137893  Video         1          11             5          3
# 446             96749  Photo         1           3             1          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
#Detect outliers
outliers = df[df['Lifetime Post Total Reach'] > df['Lifetime Post Total Reach'].quantile(0.95)]
outliers
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 71             137893  Video         1          11             5          3
# 101            137020  Photo         2          10             4          3
# 105            137020  Photo         1          10             2          4
# 140            136013   Link         1          10             4          3
# 203            132817  Photo         3           8             2         10
# 227            131728  Photo         1           7             4         10
# 244            130791  Photo         2           7             3          5
# 271            128032  Photo         1           7             3         10
# 272            127082  Photo         1           7             3          3
# 277            126424  Video         1           6             2         13
# 279            126345  Photo         1           6             2          3
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Load Facebook metrics dataset
df = pd.read_csv("dataset_Facebook.csv", sep=';')

# Data preprocessing
X = df.drop(columns=['Lifetime Post Consumers'])
y = df['Lifetime Post Consumers']

# One-hot encoding for categorical variables
X_encoded = pd.get_dummies(X, columns=['Type'])

# Impute missing values with the mean of each column
X_encoded.fillna(X_encoded.mean(), inplace=True)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Model training
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Model evaluation
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 16759.047675000013

# %%
print(df.columns)
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 53.03270000000001
# Mean Squared Error: 16759.047675000013
# Root Mean Squared Error: 129.4567405545189

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for Lifetime Post Total Reach
plt.figure(figsize=(10, 6))
sns.histplot(df['Lifetime Post Total Reach'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Lifetime Post Total Reach')
plt.xlabel('Lifetime Post Total Reach')
plt.ylabel('Frequency')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# # Convert y_pred to binary values (assuming it's regression)
# y_pred_binary = np.where(y_pred > y_pred.mean(), 1, 0)
# y_test_binary = np.where(y_test > y_test.mean(), 1, 0)

# # Create confusion matrix
# cm = confusion_matrix(y_test_binary, y_pred_binary)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.show()

from sklearn.metrics import accuracy_score
# Convert y_pred to binary values (assuming it's regression)
y_pred_binary = np.where(y_pred > y_pred.mean(), 1, 0)
y_test_binary = np.where(y_test > y_test.mean(), 1, 0)
# Create confusion matrix
cm = confusion_matrix(y_test_binary, y_pred_binary)
# Compute accuracy
accuracy = accuracy_score(y_test_binary, y_pred_binary)

# Plot confusion matrix with accuracy
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Confusion Matrix')
plt.show()
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.97

# %%
import matplotlib.pyplot as plt

# Group by Type and calculate mean likes and shares
grouped_df = df.groupby('Type')[['like', 'share']].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))

# Bar graph for average likes
plt.subplot(2, 1, 1)
plt.bar(grouped_df['Type'], grouped_df['like'], color='skyblue')
plt.title('Average Likes by Post Type')
plt.xlabel('Post Type')
plt.ylabel('Average Likes')

# Line plot for average shares
plt.subplot(2, 1, 2)
plt.plot(grouped_df['Type'], grouped_df['share'], marker='o', color='orange', linestyle='-')
plt.title('Average Shares by Post Type')
plt.xlabel('Post Type')
plt.ylabel('Average Shares')

plt.tight_layout()
plt.show()

# %%
# Compute accuracy, mean squared error, and other metrics before removal of outliers
accuracy_before = accuracy_score(y_test_binary, y_pred_binary)
mse_before = mean_squared_error(y_test, y_pred)
# Compute other metrics as needed

# Compute accuracy, mean squared error, and other metrics after removal of outliers
accuracy_after = accuracy_score(y_test_binary, y_pred_binary)
mse_after = mean_squared_error(y_test, y_pred)
# Compute other metrics as needed

# Before removal of outliers
plt.figure(figsize=(10, 12))
plt.subplot(2, 1, 1)
sns.regplot(x='like', y='share', data=df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title(f'Regression Line for Likes vs Shares\n(Accuracy: {accuracy_before:.5f}, MSE: {mse_before:.5f})')
plt.xlabel('Likes')
plt.ylabel('Shares')
plt.grid(True)

# After removal of outliers
plt.subplot(2, 1, 2)
sns.regplot(x='like', y='share', data=outliers, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title(f'Regression Line for Likes vs Shares\n(Accuracy: {accuracy_after:.5f}, MSE: {mse_after:.5f})')
plt.xlabel('Likes')
plt.ylabel('Shares')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Get column names
columns = df.columns

# Plot histograms for each parameter
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col], bins=20, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Replace df.columns with your actual column names if they are different

# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Creating a correlation matrix
correlation_matrix = numeric_df.corr()

# Plotting the heatmap
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Adding title
plt.title('Correlation Heatmap')

# Rotating x-axis labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45)

# Rotating y-axis labels
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

# Displaying the heatmap
plt.show()
