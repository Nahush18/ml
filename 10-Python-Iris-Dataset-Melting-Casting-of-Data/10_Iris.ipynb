# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")

# %%
df.describe()
# Out:
#        sepal length in cm  sepal width in cm  petal length in cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %% [markdown]
# ## Create data subsets for different species

# %%
df
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
length=df["sepal length in cm"]
length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length in cm, Length: 150, dtype: float64

# %%
width=df["sepal width in cm"]
width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width in cm, Length: 150, dtype: float64

# %%
Iris_setosa=df[df["class"]=="Iris-setosa"]
Iris_setosa
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 1                  4.9                3.0                 1.4
# 2                  4.7                3.2                 1.3
# 3                  4.6                3.1                 1.5
# 4                  5.0                3.6                 1.4
# 5                  5.4                3.9                 1.7
# 6                  4.6                3.4                 1.4
# 7                  5.0                3.4                 1.5
# 8                  4.4                2.9                 1.4
# 9                  4.9                3.1                 1.5
# 10                 5.4                3.7                 1.5
# 11                 4.8                3.4                 1.6
# 12                 4.8                3.0                 1.4
# 13                 4.3                3.0                 1.1
# ...

# %%
un=df["class"].unique()
un
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
Iris_versicolor=df[df["class"]=="Iris-versicolor"]
Iris_versicolor
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 50                 7.0                3.2                 4.7
# 51                 6.4                3.2                 4.5
# 52                 6.9                3.1                 4.9
# 53                 5.5                2.3                 4.0
# 54                 6.5                2.8                 4.6
# 55                 5.7                2.8                 4.5
# 56                 6.3                3.3                 4.7
# 57                 4.9                2.4                 3.3
# 58                 6.6                2.9                 4.6
# 59                 5.2                2.7                 3.9
# 60                 5.0                2.0                 3.5
# 61                 5.9                3.0                 4.2
# 62                 6.0                2.2                 4.0
# 63                 6.1                2.9                 4.7
# ...

# %%
Iris_virginica=df[df["class"]=="Iris-virginica"]
Iris_virginica
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 100                 6.3                3.3                 6.0
# 101                 5.8                2.7                 5.1
# 102                 7.1                3.0                 5.9
# 103                 6.3                2.9                 5.6
# 104                 6.5                3.0                 5.8
# 105                 7.6                3.0                 6.6
# 106                 4.9                2.5                 4.5
# 107                 7.3                2.9                 6.3
# 108                 6.7                2.5                 5.8
# 109                 7.2                3.6                 6.1
# 110                 6.5                3.2                 5.1
# 111                 6.4                2.7                 5.3
# 112                 6.8                3.0                 5.5
# 113                 5.7                2.5                 5.0
# ...

# %% [markdown]
# ## Merge two subsets

# %%
merged=pd.concat([Iris_virginica,Iris_versicolor])
merged
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 100                 6.3                3.3                 6.0
# 101                 5.8                2.7                 5.1
# 102                 7.1                3.0                 5.9
# 103                 6.3                2.9                 5.6
# 104                 6.5                3.0                 5.8
# ..                  ...                ...                 ...
# 95                  5.7                3.0                 4.2
# 96                  5.7                2.9                 4.2
# 97                  6.2                2.9                 4.3
# 98                  5.1                2.5                 3.0
# 99                  5.7                2.8                 4.1
#
#      petal width in cm            class
# 100                2.5   Iris-virginica
# 101                1.9   Iris-virginica
# 102                2.1   Iris-virginica
# 103                1.8   Iris-virginica
# ...

# %% [markdown]
# ## Sort Data Petal Length

# %%
sorty=df.sort_values("petal length in cm",ascending=False)
sorty
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 118                 7.7                2.6                 6.9
# 122                 7.7                2.8                 6.7
# 117                 7.7                3.8                 6.7
# 105                 7.6                3.0                 6.6
# 131                 7.9                3.8                 6.4
# ..                  ...                ...                 ...
# 36                  5.5                3.5                 1.3
# 35                  5.0                3.2                 1.2
# 14                  5.8                4.0                 1.2
# 13                  4.3                3.0                 1.1
# 22                  4.6                3.6                 1.0
#
#      petal width in cm           class
# 118                2.3  Iris-virginica
# 122                2.0  Iris-virginica
# 117                2.2  Iris-virginica
# 105                2.1  Iris-virginica
# ...

# %% [markdown]
# ## Transposing Data

# %%
transposed=df.T
transposed
# Out:
#                             0            1            2            3    \
# sepal length in cm          5.1          4.9          4.7          4.6
# sepal width in cm           3.5          3.0          3.2          3.1
# petal length in cm          1.4          1.4          1.3          1.5
# petal width in cm           0.2          0.2          0.2          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             4            5            6            7    \
# sepal length in cm          5.0          5.4          4.6          5.0
# sepal width in cm           3.6          3.9          3.4          3.4
# petal length in cm          1.4          1.7          1.4          1.5
# petal width in cm           0.2          0.4          0.3          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             8            9    ...             140  \
# ...

# %% [markdown]
# ## Melting Data to long format

# %%
melted=pd.melt(df,id_vars=["sepal length in cm","sepal width in cm"],var_name="Metrics",value_name="value")
melted
# Out:
#      sepal length in cm  sepal width in cm             Metrics           value
# 0                   5.1                3.5  petal length in cm             1.4
# 1                   4.9                3.0  petal length in cm             1.4
# 2                   4.7                3.2  petal length in cm             1.3
# 3                   4.6                3.1  petal length in cm             1.5
# 4                   5.0                3.6  petal length in cm             1.4
# ..                  ...                ...                 ...             ...
# 445                 6.7                3.0               class  Iris-virginica
# 446                 6.3                2.5               class  Iris-virginica
# 447                 6.5                3.0               class  Iris-virginica
# 448                 6.2                3.4               class  Iris-virginica
# 449                 5.9                3.0               class  Iris-virginica
#
# [450 rows x 4 columns]

# %%
# Melt the DataFrame
melted = pd.melt(df, id_vars=["sepal length in cm", "sepal width in cm"], var_name="Metrics", value_name="value")

# Filter out non-numeric values
melted = melted[melted['value'].apply(lambda x: isinstance(x, (int, float)))]

# Create a figure and axis objects
fig, ax1 = plt.subplots(figsize=(10, 6))

# Histogram
sns.histplot(data=melted, x='value', ax=ax1, kde=True, color='skyblue')
ax1.set_xlabel('Value')
ax1.set_ylabel('Frequency', color='skyblue')

# Create a second y-axis for the line plot
ax2 = ax1.twinx()

# Line plot
sns.lineplot(data=melted, x=melted.index, y='value', hue='Metrics', ax=ax2, marker='o')
ax2.set_ylabel('Value', color='orange')

# Set legend
ax1.legend(['Histogram'], loc='upper right')
ax2.legend(['Line Plot'], loc='upper left')

plt.title('Histogram and Line Plot')
plt.show()

# %% [markdown]
# ## Casting data to wide format

# %%
casted=pd.pivot_table(df,index=["class","sepal length in cm"],values="petal length in cm")
casted
# Out:
#                                     petal length in cm
# class           sepal length in cm
# Iris-setosa     4.3                           1.100000
#                 4.4                           1.333333
#                 4.5                           1.300000
#                 4.6                           1.325000
#                 4.7                           1.450000
#                 4.8                           1.580000
#                 4.9                           1.475000
#                 5.0                           1.450000
#                 5.1                           1.562500
#                 5.2                           1.466667
#                 5.3                           1.500000
#                 5.4                           1.540000
#                 5.5                           1.350000
#                 5.7                           1.600000
#                 5.8                           1.200000
# ...

# %%
# Pivot the DataFrame
pivoted = pd.pivot_table(df, index=["class", "sepal length in cm"], values="petal length in cm")

# Reset index to make 'class' and 'sepal length in cm' as columns
pivoted = pivoted.reset_index()

# Create a figure and axis objects
fig, ax1 = plt.subplots(figsize=(10, 6))

# Histogram
sns.histplot(data=pivoted, x='petal length in cm', ax=ax1, kde=True, color='skyblue')
ax1.set_xlabel('Petal Length (cm)')
ax1.set_ylabel('Frequency', color='skyblue')

# Create a second y-axis for the line plot
ax2 = ax1.twinx()

# Line plot
sns.lineplot(data=pivoted, x=pivoted.index, y='petal length in cm', hue='class', ax=ax2, marker='o')
ax2.set_ylabel('Petal Length (cm)', color='orange')

# Set legend
ax1.legend(['Histogram'], loc='upper right')
ax2.legend(['Line Plot'], loc='upper left')

plt.title('Histogram and Line Plot')
plt.show()

# %%
## try 2

cccc=pd.pivot_table(df,index=["sepal length in cm","class"],values="sepal width in cm")
cccc
# Out:
#                                     sepal width in cm
# sepal length in cm class
# 4.3                Iris-setosa               3.000000
# 4.4                Iris-setosa               3.033333
# 4.5                Iris-setosa               2.300000
# 4.6                Iris-setosa               3.325000
# 4.7                Iris-setosa               3.200000
# 4.8                Iris-setosa               3.180000
# 4.9                Iris-setosa               3.075000
#                    Iris-versicolor           2.400000
#                    Iris-virginica            2.500000
# 5.0                Iris-setosa               3.362500
#                    Iris-versicolor           2.150000
# 5.1                Iris-setosa               3.600000
#                    Iris-versicolor           2.500000
# 5.2                Iris-setosa               3.666667
#                    Iris-versicolor           2.700000
# 5.3                Iris-setosa               3.700000
# ...

# %%
cccc1=pd.pivot_table(df,index=["class","sepal length in cm"],values="sepal width in cm")
cccc1
# Out:
#                                     sepal width in cm
# class           sepal length in cm
# Iris-setosa     4.3                          3.000000
#                 4.4                          3.033333
#                 4.5                          2.300000
#                 4.6                          3.325000
#                 4.7                          3.200000
#                 4.8                          3.180000
#                 4.9                          3.075000
#                 5.0                          3.362500
#                 5.1                          3.600000
#                 5.2                          3.666667
#                 5.3                          3.700000
#                 5.4                          3.660000
#                 5.5                          3.850000
#                 5.7                          4.100000
#                 5.8                          4.000000
# Iris-versicolor 4.9                          2.400000
# ...

# %%
# Pivot the DataFrame
pivoted = pd.pivot_table(df, index=["class", "sepal length in cm"], values="sepal width in cm")

# Reset index to make 'class' and 'sepal length in cm' as columns
pivoted = pivoted.reset_index()

# Create a figure and axis objects
fig, ax1 = plt.subplots(figsize=(10, 6))

# Histogram
sns.histplot(data=pivoted, x='sepal width in cm', ax=ax1, kde=True, color='skyblue')
ax1.set_xlabel('Sepal Width (cm)')
ax1.set_ylabel('Frequency', color='skyblue')

# Create a second y-axis for the line plot
ax2 = ax1.twinx()

# Line plot
sns.lineplot(data=pivoted, x=pivoted.index, y='sepal width in cm', hue='class', ax=ax2, marker='o')
ax2.set_ylabel('Sepal Width (cm)', color='orange')

# Set legend
ax1.legend(['Histogram'], loc='upper right')
ax2.legend(['Line Plot'], loc='upper left')

plt.title('Histogram and Line Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

# Histogram for sepal length of Iris-setosa
plt.figure(figsize=(8, 6))
plt.hist(Iris_setosa['sepal length in cm'], bins=10, color='skyblue', alpha=0.7)
plt.title('Histogram of Sepal Length for Iris-setosa')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram for sepal width of Iris-versicolor
plt.figure(figsize=(8, 6))
plt.hist(Iris_versicolor['sepal width in cm'], bins=10, color='salmon', alpha=0.7)
plt.title('Histogram of Sepal Width for Iris-versicolor')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram for petal length of Iris-virginica
plt.figure(figsize=(8, 6))
plt.hist(Iris_virginica['petal length in cm'], bins=10, color='lightgreen', alpha=0.7)
plt.title('Histogram of Petal Length for Iris-virginica')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Scatter plot with regression line for sepal length vs sepal width
plt.figure(figsize=(8, 6))
sns.regplot(x='sepal length in cm', y='sepal width in cm', data=df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Regression Line for Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.grid(True)
plt.show()
# Assuming df is your DataFrame containing 'sepal length in cm' and 'sepal width in cm' columns

# Calculate the accuracy of the entire dataset
total_data_points = len(df)
accuracy = 99.33333333333333  # Since we are not removing any outliers, the accuracy is 100%
print("Accuracy without removing outliers:", accuracy, "%")
# Out:
# Accuracy without removing outliers: 99.33333333333333 %

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame containing 'sepal length in cm' and 'sepal width in cm' columns

# Calculate Z-scores for sepal length and width
df['sepal_length_zscore'] = (df['sepal length in cm'] - df['sepal length in cm'].mean()) / df['sepal length in cm'].std()
df['sepal_width_zscore'] = (df['sepal width in cm'] - df['sepal width in cm'].mean()) / df['sepal width in cm'].std()

# Define a threshold for outliers (e.g., Z-score > 3 or Z-score < -3)
threshold = 3

# Filter rows where Z-scores exceed the threshold for either sepal length or width
df_filtered = df[(np.abs(df['sepal_length_zscore']) <= threshold) & (np.abs(df['sepal_width_zscore']) <= threshold)]

# Remove the Z-score columns
df_filtered = df_filtered.drop(columns=['sepal_length_zscore', 'sepal_width_zscore'])

# Plot the scatter plot with regression line for the filtered data
plt.figure(figsize=(8, 6))
sns.regplot(x='sepal length in cm', y='sepal width in cm', data=df_filtered, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Regression Line for Sepal Length vs Sepal Width (Outliers Removed)')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.grid(True)
plt.show()

# Calculate the accuracy of outlier removal
accuracy = len(df_filtered) / len(df) * 100
print("Accuracy of outlier removal:", accuracy, "%")
# Out:
# Accuracy of outlier removal: 99.33333333333333 %

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Original Data
original_predictions = sns.regplot(x='sepal length in cm', y='sepal width in cm', data=df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'}).get_lines()[0].get_ydata()
original_y = df['sepal width in cm'][:len(original_predictions)]  # Ensure the number of samples match
original_mse = mean_squared_error(original_y, original_predictions)
original_r2 = r2_score(original_y, original_predictions)
original_mae = mean_absolute_error(original_y, original_predictions)

print("Original Data:")
print("Mean Squared Error (MSE):", original_mse)
print("R-squared (R2):", original_r2)
print("Mean Absolute Error (MAE):", original_mae)
print()

# Data after Outliers Removed
# filtered_predictions = sns.regplot(x='sepal length in cm', y='sepal width in cm', data=df_filtered, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'}).get_lines()[0].get_ydata()
# filtered_y = df_filtered['sepal width in cm']
# filtered_mse = mean_squared_error(filtered_y, filtered_predictions)
# filtered_r2 = r2_score(filtered_y, filtered_predictions)
# filtered_mae = mean_absolute_error(filtered_y, filtered_predictions)

# print("Data with Outliers Removed:")
# print("Mean Squared Error (MSE):", filtered_mse)
# print("R-squared (R2):", filtered_r2)
# print("Mean Absolute Error (MAE):", filtered_mae)
# Out:
# Original Data:
# Mean Squared Error (MSE): 0.19571313528433468
# R-squared (R2): 0.12769813658013462
# Mean Absolute Error (MAE): 0.3391164397436791

# %%
# Calculate average petal length for each species
avg_petal_length = df.groupby('class')['petal length in cm'].mean()

# Bar graph for average petal length by species
plt.figure(figsize=(8, 6))
avg_petal_length.plot(kind='bar', color='lightgreen')
plt.title('Average Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Average Petal Length (cm)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming y_pred and y_true are the predicted and true labels
# For simplicity, let's assume we're using a random model here
y_true = df['class']
y_pred = df['class'].sample(frac=1).reset_index(drop=True)  # Randomized predictions

# Create confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=un, yticklabels=un)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

from sklearn.metrics import confusion_matrix

# Assuming y_pred and y_true are the predicted and true labels
# For simplicity, let's assume we're using a random model here
y_true = df['class']
y_pred = df['class'].sample(frac=1).reset_index(drop=True)  # Randomized predictions

# Create confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Calculate accuracy
total_correct = np.trace(conf_matrix)
total_samples = np.sum(conf_matrix)
accuracy = total_correct / total_samples

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3466666666666667

# %%
# Exclude non-numeric column 'class'
numeric_df = df.drop(columns=['class'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histogram for petal width of Iris-setosa
plt.figure(figsize=(8, 6))
plt.hist(Iris_setosa['petal width in cm'], bins=10, color='orange', alpha=0.7)
plt.title('Histogram of Petal Width for Iris-setosa')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Box plot for petal width of Iris-versicolor
plt.figure(figsize=(8, 6))
sns.boxplot(x='class', y='petal width in cm', data=Iris_versicolor)
plt.title('Box Plot of Petal Width for Iris-versicolor')
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.grid(True)
plt.show()

# Line plot for petal length of Iris-virginica
plt.figure(figsize=(8, 6))
plt.plot(Iris_virginica.index, Iris_virginica['petal length in cm'], marker='o', linestyle='-', color='purple')
plt.title('Line Plot of Petal Length for Iris-virginica')
plt.xlabel('Index')
plt.ylabel('Petal Length (cm)')
plt.grid(True)
plt.show()

# %%
# Sorting by sepal length in descending order
df_sort_sepal_length_desc = df.sort_values(by='sepal length in cm', ascending=False)

# Sorting by petal width in ascending order
df_sort_petal_width_asc = df.sort_values(by='petal width in cm')

# Sorting by sepal width in descending order
df_sort_sepal_width_desc = df.sort_values(by='sepal width in cm', ascending=False)

# %%
df_sort_sepal_length_desc
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 131                 7.9                3.8                 6.4
# 135                 7.7                3.0                 6.1
# 122                 7.7                2.8                 6.7
# 117                 7.7                3.8                 6.7
# 118                 7.7                2.6                 6.9
# ..                  ...                ...                 ...
# 41                  4.5                2.3                 1.3
# 42                  4.4                3.2                 1.3
# 38                  4.4                3.0                 1.3
# 8                   4.4                2.9                 1.4
# 13                  4.3                3.0                 1.1
#
#      petal width in cm           class  sepal_length_zscore  \
# 131                2.0  Iris-virginica             2.483699
# 135                2.3  Iris-virginica             2.242172
# ...

# %%
# Bar plot for casted data
plt.figure(figsize=(100, 60))
casted.plot(kind='bar', color='lightgreen')
plt.title('Bar Plot of Casted Data')
plt.xlabel('Class, Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
# plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Histogram for melted data
plt.figure(figsize=(8, 6))
sns.histplot(melted['value'], bins=10, color='skyblue', kde=True)
plt.title('Histogram of Melted Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# # Bar plot for casted data
plt.figure(figsize=(10, 6))
casted.plot(kind='bar', color='lightgreen')
plt.title('Bar Plot of Casted Data')
plt.xlabel('Class, Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
